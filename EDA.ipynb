# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # 1. Understanding the Dataset

# %% [markdown]
# Load the dataset (pandas.read_csv / read_excel, etc.)

# %%
data = pd.read_csv('cardio_train.csv',sep=";")

# %% [markdown]
# Check dataset shape (.shape) → number of rows & columns

# %%
data.shape
# Out:
# (70000, 13)

# %% [markdown]
# Preview data (.head(), .tail())

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# Check column names (.columns)

# %%
data.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# Check data types (.dtypes)

# %%
data.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# Check info summary (.info())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# Check for missing values (.isnull().sum())

# %%
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# Basic statistics (.describe()) for numerical & categorical data

# %%
data.describe().T
# Out:
#                count          mean           std      min       25%      50%  \
# id           70000.0  49972.419900  28851.302323      0.0  25006.75  50001.5
# age          70000.0  19468.865814   2467.251667  10798.0  17664.00  19703.0
# gender       70000.0      1.349571      0.476838      1.0      1.00      1.0
# height       70000.0    164.359229      8.210126     55.0    159.00    165.0
# weight       70000.0     74.205690     14.395757     10.0     65.00     72.0
# ap_hi        70000.0    128.817286    154.011419   -150.0    120.00    120.0
# ap_lo        70000.0     96.630414    188.472530    -70.0     80.00     80.0
# cholesterol  70000.0      1.366871      0.680250      1.0      1.00      1.0
# gluc         70000.0      1.226457      0.572270      1.0      1.00      1.0
# smoke        70000.0      0.088129      0.283484      0.0      0.00      0.0
# alco         70000.0      0.053771      0.225568      0.0      0.00      0.0
# ...

# %% [markdown]
# # 2. Understanding Data Types

# %% [markdown]
# Separate numerical, categorical, and datetime columns

# %%
data.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# Convert data types if necessary (astype())

# %%
# no conversion needed

# %% [markdown]
# # 3. Handling Missing Values

# %% [markdown]
# Identify missing values (isna(), isnull())

# %%
data.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# Decide strategy:

# %%
# no missing value found

# %% [markdown]
# Drop missing rows/columns

# %% [markdown]
# Fill missing values with mean/median/mode

# %% [markdown]
# Fill missing values with forward/backward fill (ffill, bfill)

# %% [markdown]
# # 4. Handling Duplicates

# %% [markdown]
# Check duplicates (.duplicated())

# %%
# remove id column
# run this cell only once
data = data.iloc[::,1::]
data.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# np.int64(24)

# %% [markdown]
# Remove duplicates (.drop_duplicates())

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (69976, 12)

# %% [markdown]
# # converting age

# %%
# .25 is because every 4 years is a leap year
data['age'] = data['age'] / 365.25

# %% [markdown]
# # 5. Exploratory Visualization

# %% [markdown]
# ## a) Univariate Analysis
#
# ### Numerical features:

# %% [markdown]
# Histogram (sns.histplot, plt.hist)

# %%
data.hist(bins=30,figsize=(15, 10))
plt.show()

# %% [markdown]
# Boxplot (sns.boxplot, plt.boxplot)

# %%
num_cols = data.select_dtypes(include=np.number).columns

# Subplot grid size
rows = int(np.ceil(len(num_cols) / 3))
fig, axes = plt.subplots(rows, 3, figsize=(15, 4 * rows))

axes = axes.flatten()

# Plot each column
for i, col in enumerate(num_cols):
    sb.boxplot(y=data[col], ax=axes[i])
    axes[i].set_title(col)

# Remove empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## b) Bivariate Analysis
#
# ### Numerical vs Numerical:

# %% [markdown]
# Scatter plot (sns.scatterplot)

# %%
sb.scatterplot(data=data['age'])
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# Correlation matrix (.corr(), sns.heatmap)

# %%
corr = data.corr()

# %%
sb.heatmap(data=corr,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ## c) Multivariate Analysis

# %% [markdown]
# Pairplot (sns.pairplot)

# %%
sb.pairplot(data=data)
